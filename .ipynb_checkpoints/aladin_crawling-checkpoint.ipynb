# %% [markdown]
# ### 19금로그인 부분 빼고 가능

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

driver = webdriver.Chrome()
url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1'
driver.get(url)

def star_check(book_num, promo):
    try:
        x = driver.find_element(
            By.XPATH,
            f'//*[@id="Myform"]/div[{book_num}]/table/tbody/tr/td[3]/table/tbody/tr[1]/td[1]/div[1]/ul/li[{promo}]/span'
        ).text
        
        return x
    
    except:
        return float('nan')

def get_genre(urls):
    genre = []
    
    for u in urls:
        driver.execute_script(f'''window.open("{u}","_blank");''')

        # 맨 마지막에 열린 탭으로 이동
        driver.switch_to.window(driver.window_handles[-1])

        g = driver.find_element(By.XPATH, '//*[@id="ulCategory"]').text
        genre.append(g)

        driver.close()

        # 맨 마지막에 열린 탭으로 이동
        driver.switch_to.window(driver.window_handles[-1])
        
    return genre

def next_page(p):  # 2~22
    xpath = '//*[@id="newbg_body"]/div[3]/ul'
    page = driver.find_element(
        By.XPATH, xpath + f'/li[{p}]')
    
    if not page.is_displayed():
        next_button = driver.find_element(By.XPATH, xpath + f'/li[22]')
        next_button.click()
        
    print(page.text)
    page.click()

# 3~52
result = pd.DataFrame()

for page_num in range(3,22):
    book_name = []
    book_price = []
    discount_price = []
    star_rate = []
    urls = []
    
    for book_num in range(3,53):
        xpath = f'//*[@id="Myform"]/div[{book_num}]/table/tbody/tr/td[3]/table/tbody/tr[1]/td[1]/div[1]/ul/'

        try:  # 행사 정보가 있는 경우        
            driver.find_element(By.XPATH, xpath + 'li[2]/a[1]/b')
            promo = 1        
        except: promo = 0

        x = driver.find_element(By.XPATH, xpath + f'li[{1+promo}]/a[1]/b').text        
        u = driver.find_element(By.XPATH, xpath + f'li[{1+promo}]/a[1]').get_attribute('href')
        p = driver.find_element(By.XPATH, xpath + f'li[{3+promo}]/span[1]').text
        d = driver.find_element(By.XPATH, xpath + f'li[{3+promo}]/span[2]/b/span').text
        s = star_check(book_num, 4+promo)

        book_name.append(x)
        book_price.append(p)
        discount_price.append(d)
        star_rate.append(s)
        urls.append(u)

    genre = get_genre(urls)        
    temp = pd.DataFrame([book_name, book_price, discount_price, star_rate, urls, genre])
    result = pd.concat([result, temp], axis=0)
    next_page(page_num)
    
result.index = ['name', 'price', 'discount_price', 'star', 'url', 'genre']
result = result.T

# %%
import pandas as pd
result = pd.DataFrame()
result.index = ['name', 'price', 'discount_price', 'star', 'url', 'genre']
result
# Out:
# Empty DataFrame
# Columns: []
# Index: [name, price, discount_price, star, url, genre]

# %% [markdown]
# ### 19금 로그인 수정중 에러 2페이지 에서는 pass 근데 651~ 부터에서 2개 는 안됨.

# %%
from selenium import webdriver  
from selenium.webdriver.common.by import By
import pandas as pd              

driver = webdriver.Chrome()
url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1'
driver.get(url)

def star_check(book_num, promo):
    try:
        x = driver.find_element(
            By.XPATH,
            f'//*[@id="Myform"]/div[{book_num}]/table/tbody/tr/td[3]/table/tbody/tr[1]/td[1]/div[1]/ul/li[{promo}]/span'
        ).text
        
        return x
    
    except:
        return float('nan')

def get_genre(urls):
    genre = []
    
    for book_num in range(3,53):
        u = urls[book_num - 3]

        img = driver.find_elements(
                By.XPATH,
                f'//*[@id="Myform"]/div[{book_num}]/table/tbody/tr/td[2]/table/tbody/tr[1]/td/div[2]/a/img'
        )
        
        if img != []:
            genre.append(float('nan'))
        else:
            driver.execute_script(f'''window.open("{u}","_blank");''')

            # 맨 마지막에 열린 탭으로 이동
            driver.switch_to.window(driver.window_handles[-1])
            
            # #@!
            driver.find_element(
                By.XPATH,
                f'//*[@id="ulCategory"]/li'
            )
            
            driver.close()

        # 맨 마지막에 열린 탭으로 이동
        driver.switch_to.window(driver.window_handles[-1])
        
    return genre

def next_page(p):  # 2~22
    xpath = '//*[@id="newbg_body"]/div[3]/ul'
    page = driver.find_element(
        By.XPATH, xpath + f'/li[{p}]')
    
    if not page.is_displayed():
        next_button = driver.find_element(By.XPATH, xpath + f'/li[22]')
        next_button.click()
        
    print(page.text)
    page.click()

# 3~52
result = pd.DataFrame()

for page_num in range(3,22):
    book_name = []
    book_price = []
    discount_price = []
    star_rate = []
    urls = []
    
    for book_num in range(3,53):
        xpath = f'//*[@id="Myform"]/div[{book_num}]/table/tbody/tr/td[3]/table/tbody/tr[1]/td[1]/div[1]/ul/'

        try:  # 행사 정보가 있는 경우        
            driver.find_element(By.XPATH, xpath + 'li[2]/a[1]/b')
            promo = 1        
        except: promo = 0

        x = driver.find_element(By.XPATH, xpath + f'li[{1+promo}]/a[1]/b').text        
        u = driver.find_element(By.XPATH, xpath + f'li[{1+promo}]/a[1]').get_attribute('href')
        p = driver.find_element(By.XPATH, xpath + f'li[{3+promo}]/span[1]').text
        d = driver.find_element(By.XPATH, xpath + f'li[{3+promo}]/span[2]/b/span').text
        s = star_check(book_num, 4+promo)

        book_name.append(x)
        book_price.append(p)
        discount_price.append(d)
        star_rate.append(s)
        urls.append(u)
    
    genre = get_genre(urls)        
    temp = pd.DataFrame([book_name, book_price, discount_price, star_rate, urls, genre])
    result = pd.concat([result, temp], axis=0)
    next_page(page_num)
    
result.index = ['name', 'price', 'discount_price', 'star', 'url', 'genre']
result = result.T

# %% [markdown]
# # 604일 한번 돌려보기

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoAlertPresentException, UnexpectedAlertPresentException
from selenium.webdriver.common.alert import Alert
import pandas as pd

driver = webdriver.Chrome()
url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1'
driver.get(url)

def handle_alert():
    try:
        alert = Alert(driver)
        alert.accept()  # or alert.dismiss()
    except NoAlertPresentException:
        pass

def star_check(book_num, promo):
    try:
        x = driver.find_element(
            By.XPATH,
            f'//*[@id="Myform"]/div[{book_num}]/table/tbody/tr/td[3]/table/tbody/tr[1]/td[1]/div[1]/ul/li[{promo}]/span'
        ).text
        return x
    except:
        return float('nan')

def get_genre(urls):
    genre = []
    for book_num in range(3, 53):
        u = urls[book_num - 3]

        img = driver.find_elements(
            By.XPATH,
            f'//*[@id="Myform"]/div[{book_num}]/table/tbody/tr/td[2]/table/tbody/tr[1]/td/div[2]/a/img'
        )

        if img != []:
            genre.append(float('nan'))
        else:
            driver.execute_script(f'''window.open("{u}","_blank");''')

            driver.switch_to.window(driver.window_handles[-1])

            try:
                handle_alert()  # Handle alert if present

                driver.find_element(
                    By.XPATH,
                    f'//*[@id="ulCategory"]/li'
                )

                genre.append(driver.find_element(
                    By.XPATH,
                    f'//*[@id="ulCategory"]/li'
                ).text)
            except:
                genre.append(float('nan'))

            driver.close()

        driver.switch_to.window(driver.window_handles[-1])

    return genre

def next_page(p):  # 2~22
    xpath = '//*[@id="newbg_body"]/div[3]/ul'
    page = driver.find_element(
        By.XPATH, xpath + f'/li[{p}]')

    if not page.is_displayed():
        next_button = driver.find_element(By.XPATH, xpath + f'/li[22]')
        next_button.click()

    print(page.text)
    page.click()

result = pd.DataFrame()

for page_num in range(3, 22):
    book_name = []
    book_price = []
    discount_price = []
    star_rate = []
    urls = []

    for book_num in range(3, 53):
        xpath = f'//*[@id="Myform"]/div[{book_num}]/table/tbody/tr/td[3]/table/tbody/tr[1]/td[1]/div[1]/ul/'

        try:  # 행사 정보가 있는 경우
            driver.find_element(By.XPATH, xpath + 'li[2]/a[1]/b')
            promo = 1
        except:
            promo = 0

        x = driver.find_element(By.XPATH, xpath + f'li[{1 + promo}]/a[1]/b').text
        u = driver.find_element(By.XPATH, xpath + f'li[{1 + promo}]/a[1]').get_attribute('href')
        p = driver.find_element(By.XPATH, xpath + f'li[{3 + promo}]/span[1]').text
        d = driver.find_element(By.XPATH, xpath + f'li[{3 + promo}]/span[2]/b/span').text
        s = star_check(book_num, 4 + promo)

        book_name.append(x)
        book_price.append(p)
        discount_price.append(d)
        star_rate.append(s)
        urls.append(u)

    genre = get_genre(urls)
    temp = p
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[1], line 108
#     105     star_rate.append(s)
#     106     urls.append(u)
# --> 108 genre = get_genre(urls)
#     109 temp = p
#
# Cell In[1], line 60, in get_genre(urls)
#      57         except:
#      58             genre.append(float('nan'))
# ---> 60         driver.close()
#      62     driver.switch_to.window(driver.window_handles[-1])
#      64 return genre
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.close(self)
#     450 def close(self) -> None:
#     451     """Closes the current window.
#     452
#     453     :Usage:
#    (...)
#     456             driver.close()
#     457     """
# --> 458     self.execute(Command.CLOSE)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=125.0.6422.141)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF64A821F52+60322]
# 	(No symbol) [0x00007FF64A79CEC9]
# 	(No symbol) [0x00007FF64A657EBA]
# 	(No symbol) [0x00007FF64A62D5A5]
# 	(No symbol) [0x00007FF64A6D36B7]
# 	(No symbol) [0x00007FF64A6DA812]
# 	(No symbol) [0x00007FF64A6CC1E0]
# 	(No symbol) [0x00007FF64A699617]
# 	(No symbol) [0x00007FF64A69A211]
# 	GetHandleVerifier [0x00007FF64AB394AD+3301629]
# 	GetHandleVerifier [0x00007FF64AB836D3+3605283]
# 	GetHandleVerifier [0x00007FF64AB79450+3563680]
# 	GetHandleVerifier [0x00007FF64A8D4326+790390]
# 	(No symbol) [0x00007FF64A7A750F]
# 	(No symbol) [0x00007FF64A7A3404]
# 	(No symbol) [0x00007FF64A7A3592]
# 	(No symbol) [0x00007FF64A792F9F]
# 	BaseThreadInitThunk [0x00007FF834A7257D+29]
# 	RtlUserThreadStart [0x00007FF8358CAA48+40]
